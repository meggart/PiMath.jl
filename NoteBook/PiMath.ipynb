# %%
using PiMath
using Gadfly

# %% [markdown]
# Some simple math

# %%
x=pi+2pi
# Out:
# 3π

# %%
x/3
# Out:
# 1.0π

# %% [markdown]
# Type promotion should work as expected

# %%
x-(4//3)*pi
# Out:
# 5π/3

# %%
x+1
# Out:
# 10.42477796076938

# %%
y=2pi
x/y
# Out:
# 1.5

# %% [markdown]
# We can define Ranges

# %%
range1=linspace(0,4pi,100)
# Out:
# 0.0π:0.04040404040404041π:4.0π

# %% [markdown]
# And we get nice axes labels

# %%
y=sin(range1);
plot(x=range1,y=y)
# Out:
# Plot(...)

# %% [markdown]
# Same for arrays

# %%
pirange2=[x*pi for x=0:0.01:10]
plot(x=pirange2,y=cos(pirange2),Geom.line)
# Out:
# Plot(...)
